# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# Create a DataFrame with the provided data
data = {
    'Variables': ['NDBI', 'NDVI', 'NDWI', 'SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B6', 'SR_B7', 'aspect', 'elevation', 'slope'],
    'Ernakulam': [254.0556431, 267.5053693, 255.0762454, 246.1209122, 260.5171894, 247.6151772, 243.7807688, 250.9188143, 258.456088, 260.7472461, 268.2004926, 298.1949931, 279.433539],
    'Nhamatanda': [169.8577687, 187.4537238, 167.1979491, 193.6386215, 185.6034298, 201.9769669, 186.065934, 177.8915231, 179.9296757, 184.6590368, 180.0431315, 250.282296, 207.7976819],
    'Shikarpur': [296.1321303, 278.5933829, 278.7844376, 300.4910811, 260.6205928, 270.0289735, 257.2437688, 289.9397299, 275.750907, 285.1240404, 282.729171, 312.2595384, 289.7281465],
    'Sylhet': [179.558985, 181.471468, 186.129757, 179.9919826, 179.2194507, 188.2258508, 171.2714877, 182.0538638, 181.4106024, 178.504012, 195.7982726, 232.1534675, 197.473429],
    'Combined': [899.6045271, 915.0239439, 887.1883892, 920.2425973, 885.9606627, 907.8469684, 858.3619593, 900.8039311, 895.547273, 909.0343354, 926.7710677, 1092.890295, 974.4327963]
}

df = pd.DataFrame(data)
df.set_index('Variables', inplace=True)


# Function to plot bar charts for each city and for the combined values using seaborn with separate sorting and reversed colors
def plot_individual_sorted_bar_charts_reversed(df, palette):
    cities = ['Ernakulam', 'Nhamatanda', 'Shikarpur', 'Sylhet', 'Combined']
    for city in cities:
        df_city_sorted = df[city].sort_values(ascending=False)
        # Assign colors based on the sorted values with reversed palette
        colors = sns.color_palette(palette, len(df_city_sorted))[::-1]
        plt.figure(figsize=(12, 6))
        sns.barplot(x=df_city_sorted.index, y=df_city_sorted.values, palette=colors)
        plt.title(f'Feature Importance in {city}')
        plt.xlabel('Variables')
        plt.ylabel('Importance')
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()

# Plot the bar charts with individual sorting and reversed multi-hue purple color palette
plot_individual_sorted_bar_charts_reversed(df, "Purples")
# Out:
# C:\Users\walee\AppData\Local\Temp\ipykernel_11828\1997997014.py:26: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# C:\Users\walee\AppData\Local\Temp\ipykernel_11828\1997997014.py:26: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# C:\Users\walee\AppData\Local\Temp\ipykernel_11828\1997997014.py:26: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# C:\Users\walee\AppData\Local\Temp\ipykernel_11828\1997997014.py:26: FutureWarning:
#
#
#
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create a DataFrame with the provided data
data = {
    'Variables': ['NDBI', 'NDVI', 'NDWI', 'SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B6', 'SR_B7', 'aspect', 'elevation', 'slope'],
    'Ernakulam': [254.0556431, 267.5053693, 255.0762454, 246.1209122, 260.5171894, 247.6151772, 243.7807688, 250.9188143, 258.456088, 260.7472461, 268.2004926, 298.1949931, 279.433539],
    'Nhamatanda': [169.8577687, 187.4537238, 167.1979491, 193.6386215, 185.6034298, 201.9769669, 186.065934, 177.8915231, 179.9296757, 184.6590368, 180.0431315, 250.282296, 207.7976819],
    'Shikarpur': [296.1321303, 278.5933829, 278.7844376, 300.4910811, 260.6205928, 270.0289735, 257.2437688, 289.9397299, 275.750907, 285.1240404, 282.729171, 312.2595384, 289.7281465],
    'Sylhet': [179.558985, 181.471468, 186.129757, 179.9919826, 179.2194507, 188.2258508, 171.2714877, 182.0538638, 181.4106024, 178.504012, 195.7982726, 232.1534675, 197.473429]
}

df = pd.DataFrame(data)
df.set_index('Variables', inplace=True)

# Plotting the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df.T, annot=True, cmap="YlGnBu", cbar=True)
plt.title('Feature Importance Heatmap for Four Cities')
plt.xlabel('Variables')
plt.ylabel('Cities')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()
